# %%
import numpy as pd
import pandas as pd

# %%
business_json_file = 'yelp_academic_dataset_business.json'
df = pd.read_json(business_json_file , lines=True)
df
# Out:
#                    business_id                      name  \
# 0       Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1       mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2       tUFrWirKiKi_TAnsVWINQQ                    Target
# 3       MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4       mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# ...                        ...                       ...
# 150341  IUQopTMmYQG-qRtBk-8QnA              Binh's Nails
# 150342  c8GjPIOTGVmIemT7j5_SyQ      Wild Birds Unlimited
# 150343  _QAMST-NrQobXduilWEqSw         Claire's Boutique
# 150344  mtGm22y5c2UHNXDFAjaPNw  Cyclery & Fitness Center
# 150345  jV_XOycEzSlTx-65W906pg                   Sic Ink
#
#                                 address           city state postal_code  \
# 0                1616 Chapala St, Ste 2  Santa Barbara    CA       93101
# 1       87 Grasso Plaza Shopping Center         Affton    MO       63123
# ...

# %%
df = df[df["is_open"] == 1]
df = df.sample(n=500)
df.to_csv("Dataset_Random500.csv")
df
# Out:
#                    business_id                            name  \
# 140465  XumVmbgiePOFfxlZC8fQ2w             Holy Que Smokehouse
# 85952   EBolLF4rYM2sP_lqhVsddA                 Fresh Fit Foods
# 345     XwoXi0M66RU6Gouq-DSDHw        G Peppers Grill & Tavern
# 117694  V6bbrITJZLj5mCLQGb4jqg        Pupuseria la salvadoreña
# 31292   QkYXd12QO6N7BykYOp_8Ag                  Sansom Watches
# ...                        ...                             ...
# 149531  UK0hExwA-HTFVX-V8PsJFw            Lily's Pizza & Pasta
# 6440    NpIHuh0tMIZ-6EDmmwHvZA                         Wendy's
# 77632   Gy6tBn6lrf4AN2Gr1I8Oyg                        2637brew
# 106126  SbBLFRFqBOa3l3RabMPzcA  Evanescence Massage & Bodywork
# 6038    vkVzYZi0d2fzWkZpe28-YA                 Health Advocate
#
#                                                   address              city  \
# 140465                                 5788 Lower York Rd           Lahaska
# ...
